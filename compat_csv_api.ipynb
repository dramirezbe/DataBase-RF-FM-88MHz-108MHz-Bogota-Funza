# %%
from libs.data_request import DataRequest
from libs.data_request_csv_compat import DataRequestCsvCompat

dr = DataRequest()
compat = DataRequestCsvCompat(dr)

campaigns = {"Clean-campaign": 278}
node_ids = [1,2,3,4,5,7,9]

saved = compat.download_to_path(
    campaigns=campaigns,
    node_ids=node_ids,
    output_path="./export_csv_compat",   # carpeta destino
    split_by_campaign=True               # default
)

for camp, files in saved.items():
    print(camp, [str(p) for p in files])
# Out:
# INFO: Initialized DataRequest class with base_url: https://rsm.ane.gov.co:12443/api
# INFO: Loading data for campaigns: ['Clean-campaign'] and nodes: [1, 2, 3, 4, 5, 7, 9]
# 🚀 Starting Campaign: Clean-campaign
#   ↳ Node 1: 1page [00:04,  4.18s/page]
#   ↳ Node 2: 1page [00:04,  4.33s/page]
#   ↳ Node 3: 1page [00:04,  4.12s/page]
#   ↳ Node 4: 1page [00:04,  4.17s/page]
#   ↳ Node 5: 1page [00:04,  4.02s/page]
#   ↳ Node 7: 1page [00:01,  1.08s/page]
#   ↳ Node 9: 1page [00:04,  4.11s/page]
# INFO: Finished loading data for all campaigns and nodes.
# Clean-campaign ['export_csv_compat/Clean-campaign/Node1-Bogota.csv', 'export_csv_compat/Clean-campaign/Node2-Bogota.csv', 'export_csv_compat/Clean-campaign/Node3-Bogota.csv', 'export_csv_compat/Clean-campaign/Node4-Bogota.csv', 'export_csv_compat/Clean-campaign/Node5-Bogota.csv', 'export_csv_compat/Clean-campaign/Node7-Bogota.csv', 'export_csv_compat/Clean-campaign/Node9-Funza.csv']
